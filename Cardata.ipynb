# %% [markdown]
# <a href="https://colab.research.google.com/github/sssuhair/DSA_Assignment/blob/main/Cardata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
auto_mpg = pd.read_csv("/content/auto-mpg.csv")
cars_data = pd.read_csv("/content/cars_data.csv")

# %%
#Read the dataset to the python environment
auto_mpg
auto_mpg.head()
# Out:
#     mpg  cylinders  displacement  ... model year  origin                   car name
# 0  18.0          8         307.0  ...         70       1  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...         70       1          buick skylark 320
# 2  18.0          8         318.0  ...         70       1         plymouth satellite
# 3  16.0          8         304.0  ...         70       1              amc rebel sst
# 4  17.0          8         302.0  ...         70       1                ford torino
#
# [5 rows x 9 columns]

# %%
#4. Find the top 5 cars based on their sales price.
#df1 = df.sort_values('score',ascending = False).groupby('pidx').head(2)
#print (df1)

####Sort the values based on Sale price and take top 5 values
df1 = cars_data.sort_values('Sale Price', ascending=False).groupby('Make').head(5)
#Print first 5 values
df1.head(5)
# Out:
#             Make      Model   Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 5984  Volkswagen  Jetta III    Rachael  ...              0.06     204.9       12.6
# 1270        Audi         A6      Thorn  ...              0.16     171.3       13.0
# 3460       Lexus         LX      Aldin  ...              0.12     193.7        4.5
# 9032       Mazda       MX-6  Sylvester  ...              0.15     232.0        3.9
# 302        Lexus         ES       Brig  ...              0.21     228.1        4.7
#
# [5 rows x 20 columns]

# %%
#1. Read the dataset to the python environment.
cars_data
cars_data.head()
# Out:
#      Make    Model    Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 0  Suzuki   Vitara  Philippine  ...              0.13     200.9       11.5
# 1   Honda    S2000      Henrik  ...              0.02     158.5        8.8
# 2     BMW       Z4      Lebbie  ...              0.24     149.5       14.4
# 3  Toyota   Tacoma    Jefferey  ...              0.20     153.3       11.5
# 4    Ford  Festiva     Glendon  ...              0.18     122.0       14.9
#
# [5 rows x 20 columns]

# %%
#2: . Check for the null values present in the dataset.
cardata = cars_data.isnull()
print (cardata)
# Out:
#        Make  Model  Nickname  ...  5-yr Depreciation  Top Speed  0-60 Time
# 0     False  False     False  ...              False      False      False
# 1     False  False     False  ...              False      False      False
# 2     False  False     False  ...              False      False      False
# 3     False  False     False  ...              False      False      False
# 4     False  False     False  ...              False      False      False
# ...     ...    ...       ...  ...                ...        ...        ...
# 9995  False  False     False  ...              False      False      False
# 9996  False  False     False  ...              False      False      False
# 9997  False  False     False  ...              False      False      False
# 9998  False  False     False  ...              False      False      False
# 9999  False  False     False  ...              False      False      False
#
# [10000 rows x 20 columns]

# %%
#2: . Check for the null values present in the dataset.
autompg = auto_mpg.isnull()
print (autompg)
# Out:
#        mpg  cylinders  displacement  ...  model year  origin  car name
# 0    False      False         False  ...       False   False     False
# 1    False      False         False  ...       False   False     False
# 2    False      False         False  ...       False   False     False
# 3    False      False         False  ...       False   False     False
# 4    False      False         False  ...       False   False     False
# ..     ...        ...           ...  ...         ...     ...       ...
# 393  False      False         False  ...       False   False     False
# 394  False      False         False  ...       False   False     False
# 395  False      False         False  ...       False   False     False
# 396  False      False         False  ...       False   False     False
# 397  False      False         False  ...       False   False     False
#
# [398 rows x 9 columns]

# %%
#3. Plot a bar graph of male vs female buyers participated in the sales.
w=0.4
x=cars_data["Make"]
gender=cars_data["Buyer Gender"]
#plot.bar("gender")
male = cars_data[cars_data['Buyer Gender'] == 'Male']
female = cars_data.loc[cars_data['Buyer Gender'] == 'Female']
#plot.bar(x,male,w,label="male")
#plot.bar(x,female,w,bottom,male,label="female")
cars_data.plot.bar()
#plt.bar(female)
#plt.title("Male vs Female")
plt.ylabel("sales")
plt.xlabel("Male , Female")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py:125: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-2f65600a36e9> in <module>()
#      14 plt.xlabel("Male , Female")
#      15 plt.legend()
# ---> 16 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
# ...
